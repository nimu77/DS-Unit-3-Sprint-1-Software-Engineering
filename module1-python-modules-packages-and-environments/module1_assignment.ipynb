# %%
import pandas as pd
import numpy as np

# %%
pip install -i https://test.pypi.org/simple/ lambdata-nirmal
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
df = pd.read_csv('renthop-nyc.csv')
df.head()
# Out:
#    bathrooms  bedrooms  ... wheelchair_access common_outdoor_space
# 0        1.5         3  ...                 0                    0
# 1        1.0         2  ...                 0                    0
# 2        1.0         1  ...                 0                    0
# 3        1.0         1  ...                 0                    0
# 4        1.0         4  ...                 0                    0
#
# [5 rows x 34 columns]

# %%
from my_lambdata.my_mod_one import checks_null

checks_null(df)
# Out:
# DataFrame has some null values, please replace it or drop it.
